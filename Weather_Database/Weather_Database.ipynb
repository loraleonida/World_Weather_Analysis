# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size= 2000)
lngs = np.random.uniform(-90.000, 90.000, size= 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import CitiPy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import requests library
import requests

# Import weather_api_key
from config import weather_api_key

# %%
# Build the basic URL for the OpenWeatherMap + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tabarqah
# City not found. Skipping...
# Processing Record 2 of Set 1 | sechura
# Processing Record 3 of Set 1 | oriximina
# Processing Record 4 of Set 1 | lodja
# Processing Record 5 of Set 1 | olkusz
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | vestmannaeyjar
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | codrington
# Processing Record 11 of Set 1 | piacabucu
# Processing Record 12 of Set 1 | quatre cocos
# Processing Record 13 of Set 1 | bhawanipatna
# Processing Record 14 of Set 1 | garissa
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 19 of Set 1 | olafsvik
# Processing Record 20 of Set 1 | henties bay
# Processing Record 21 of Set 1 | loandjili
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | kazanskoye
# Processing Record 25 of Set 1 | bol
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | sohbatpur
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | shush
# Processing Record 30 of Set 1 | paso de carrasco
# Processing Record 31 of Set 1 | gorgan
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | saint-leu
# Processing Record 36 of Set 1 | nizwa
# Processing Record 37 of Set 1 | praia
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | salalah
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | ponta delgada
# Processing Record 43 of Set 1 | shache
# Processing Record 44 of Set 1 | tarauaca
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | esmeraldas
# Processing Record 47 of Set 1 | oranjemund
# Processing Record 48 of Set 1 | hit
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | arlit
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | yurya
# City not found. Skipping...
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | rocky mount
# Processing Record 7 of Set 2 | lydenburg
# Processing Record 8 of Set 2 | port said
# Processing Record 9 of Set 2 | ferkessedougou
# Processing Record 10 of Set 2 | laguna
# Processing Record 11 of Set 2 | trelew
# Processing Record 12 of Set 2 | severnoye
# Processing Record 13 of Set 2 | hofn
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | ust-tsilma
# Processing Record 16 of Set 2 | oussouye
# Processing Record 17 of Set 2 | grindavik
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | mount holly
# Processing Record 20 of Set 2 | sao joao da barra
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | maldonado
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | waw
# Processing Record 25 of Set 2 | richards bay
# Processing Record 26 of Set 2 | carndonagh
# Processing Record 27 of Set 2 | sarichioi
# Processing Record 28 of Set 2 | chuy
# Processing Record 29 of Set 2 | sarkand
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | san pedro
# Processing Record 33 of Set 2 | benguela
# Processing Record 34 of Set 2 | aquin
# Processing Record 35 of Set 2 | wilnsdorf
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | corbelia
# Processing Record 38 of Set 2 | rock sound
# Processing Record 39 of Set 2 | muros
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | bandarbeyla
# Processing Record 42 of Set 2 | namibe
# Processing Record 43 of Set 2 | izazi
# Processing Record 44 of Set 2 | yenagoa
# Processing Record 45 of Set 2 | hamilton
# Processing Record 46 of Set 2 | rajbiraj
# Processing Record 47 of Set 2 | alice
# Processing Record 48 of Set 2 | vardo
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 50 of Set 2 | biltine
# Processing Record 1 of Set 3 | gao
# Processing Record 2 of Set 3 | husavik
# Processing Record 3 of Set 3 | kita
# Processing Record 4 of Set 3 | roald
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | mbanza-ngungu
# Processing Record 7 of Set 3 | sabzevar
# Processing Record 8 of Set 3 | sao felix do xingu
# Processing Record 9 of Set 3 | san andres
# Processing Record 10 of Set 3 | pangnirtung
# Processing Record 11 of Set 3 | greenville
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | roberval
# Processing Record 16 of Set 3 | naantali
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | paamiut
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | havelock
# Processing Record 22 of Set 3 | luderitz
# Processing Record 23 of Set 3 | adrar
# Processing Record 24 of Set 3 | krivopolyanye
# City not found. Skipping...
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 3 | novi troyany
# Processing Record 28 of Set 3 | imbituba
# Processing Record 29 of Set 3 | taltal
# Processing Record 30 of Set 3 | lamu
# Processing Record 31 of Set 3 | togur
# Processing Record 32 of Set 3 | rio gallegos
# Processing Record 33 of Set 3 | ithaki
# Processing Record 34 of Set 3 | dzhalil
# Processing Record 35 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | vicuna
# Processing Record 39 of Set 3 | camacha
# Processing Record 40 of Set 3 | saint-augustin
# Processing Record 41 of Set 3 | yarim
# Processing Record 42 of Set 3 | saint-pierre
# Processing Record 43 of Set 3 | abnub
# Processing Record 44 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 45 of Set 3 | sabang
# Processing Record 46 of Set 3 | alta floresta
# Processing Record 47 of Set 3 | meulaboh
# Processing Record 48 of Set 3 | bubaque
# Processing Record 49 of Set 3 | mirpur khas
# Processing Record 50 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 4 | boddam
# Processing Record 2 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 4 | sambava
# Processing Record 4 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | ginda
# Processing Record 7 of Set 4 | carutapera
# Processing Record 8 of Set 4 | takoradi
# Processing Record 9 of Set 4 | doha
# Processing Record 10 of Set 4 | abu samrah
# Processing Record 11 of Set 4 | osakarovka
# Processing Record 12 of Set 4 | barra
# Processing Record 13 of Set 4 | villa bruzual
# Processing Record 14 of Set 4 | izhma
# Processing Record 15 of Set 4 | dalaba
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | imeni babushkina
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | pedreiras
# Processing Record 20 of Set 4 | tahta
# Processing Record 21 of Set 4 | sakaraha
# Processing Record 22 of Set 4 | tarnos
# Processing Record 23 of Set 4 | sept-iles
# Processing Record 24 of Set 4 | elizabeth city
# Processing Record 25 of Set 4 | chivilcoy
# Processing Record 26 of Set 4 | limoges
# Processing Record 27 of Set 4 | bako
# Processing Record 28 of Set 4 | dutse
# Processing Record 29 of Set 4 | mecca
# Processing Record 30 of Set 4 | sarrebourg
# Processing Record 31 of Set 4 | tucuman
# Processing Record 32 of Set 4 | gorahun
# Processing Record 33 of Set 4 | puerto ayacucho
# Processing Record 34 of Set 4 | queimadas
# Processing Record 35 of Set 4 | san rafael
# Processing Record 36 of Set 4 | cap malheureux
# Processing Record 37 of Set 4 | comodoro rivadavia
# Processing Record 38 of Set 4 | balkanabat
# Processing Record 39 of Set 4 | bonavista
# Processing Record 40 of Set 4 | riyadh
# Processing Record 41 of Set 4 | korla
# Processing Record 42 of Set 4 | asfi
# Processing Record 43 of Set 4 | saint-francois
# Processing Record 44 of Set 4 | gazli
# Processing Record 45 of Set 4 | port blair
# Processing Record 46 of Set 4 | diu
# Processing Record 47 of Set 4 | portel
# Processing Record 48 of Set 4 | lawrenceburg
# Processing Record 49 of Set 4 | turukhansk
# Processing Record 50 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 5 | puerto ayora
# Processing Record 2 of Set 5 | nusaybin
# Processing Record 3 of Set 5 | shymkent
# Processing Record 4 of Set 5 | borama
# City not found. Skipping...
# Processing Record 5 of Set 5 | bayamo
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | bathsheba
# Processing Record 8 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 5 | marsa matruh
# Processing Record 10 of Set 5 | pontes e lacerda
# Processing Record 11 of Set 5 | port dover
# Processing Record 12 of Set 5 | kentville
# Processing Record 13 of Set 5 | santa maria
# Processing Record 14 of Set 5 | uspenskoye
# Processing Record 15 of Set 5 | videira
# Processing Record 16 of Set 5 | hadrut
# Processing Record 17 of Set 5 | nsanje
# Processing Record 18 of Set 5 | umm kaddadah
# Processing Record 19 of Set 5 | teguise
# Processing Record 20 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 5 | carbonia
# Processing Record 24 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | novoorsk
# Processing Record 27 of Set 5 | panaba
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | normandin
# Processing Record 30 of Set 5 | envira
# Processing Record 31 of Set 5 | nantucket
# Processing Record 32 of Set 5 | porto walter
# Processing Record 33 of Set 5 | inongo
# Processing Record 34 of Set 5 | atar
# Processing Record 35 of Set 5 | albany
# Processing Record 36 of Set 5 | bereda
# Processing Record 37 of Set 5 | santa fe
# Processing Record 38 of Set 5 | barabinsk
# Processing Record 39 of Set 5 | aksarka
# Processing Record 40 of Set 5 | lujan
# Processing Record 41 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 5 | mikhaylovskoye
# Processing Record 43 of Set 5 | sur
# Processing Record 44 of Set 5 | westport
# Processing Record 45 of Set 5 | ravar
# Processing Record 46 of Set 5 | kharabali
# Processing Record 47 of Set 5 | dingle
# Processing Record 48 of Set 5 | general pico
# Processing Record 49 of Set 5 | kirkwall
# Processing Record 50 of Set 5 | souillac
# Processing Record 1 of Set 6 | mabaruma
# Processing Record 2 of Set 6 | olavarria
# Processing Record 3 of Set 6 | cabedelo
# Processing Record 4 of Set 6 | burica
# City not found. Skipping...
# Processing Record 5 of Set 6 | vila velha
# Processing Record 6 of Set 6 | naryan-mar
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | iquique
# Processing Record 9 of Set 6 | gornyy
# Processing Record 10 of Set 6 | victoria
# Processing Record 11 of Set 6 | pontivy
# Processing Record 12 of Set 6 | maputo
# Processing Record 13 of Set 6 | sayyan
# Processing Record 14 of Set 6 | gornopravdinsk
# Processing Record 15 of Set 6 | chatrapur
# Processing Record 16 of Set 6 | skjervoy
# Processing Record 17 of Set 6 | surskoye
# Processing Record 18 of Set 6 | oni
# Processing Record 19 of Set 6 | bam
# Processing Record 20 of Set 6 | muisne
# Processing Record 21 of Set 6 | nalut
# Processing Record 22 of Set 6 | jalu
# Processing Record 23 of Set 6 | belmonte
# Processing Record 24 of Set 6 | shieli
# Processing Record 25 of Set 6 | changji
# Processing Record 26 of Set 6 | brigantine
# Processing Record 27 of Set 6 | tera
# Processing Record 28 of Set 6 | high rock
# Processing Record 29 of Set 6 | dogondoutchi
# Processing Record 30 of Set 6 | ugoofaaru
# Processing Record 31 of Set 6 | kilindoni
# Processing Record 32 of Set 6 | cidreira
# Processing Record 33 of Set 6 | virginia beach
# Processing Record 34 of Set 6 | bafq
# Processing Record 35 of Set 6 | tessalit
# Processing Record 36 of Set 6 | zhanaozen
# Processing Record 37 of Set 6 | nata
# Processing Record 38 of Set 6 | tabou
# Processing Record 39 of Set 6 | qom
# Processing Record 40 of Set 6 | dalbandin
# Processing Record 41 of Set 6 | botelhos
# Processing Record 42 of Set 6 | sarkhej
# Processing Record 43 of Set 6 | saint marys
# Processing Record 44 of Set 6 | domoni
# Processing Record 45 of Set 6 | burgersdorp
# Processing Record 46 of Set 6 | mana
# Processing Record 47 of Set 6 | bilma
# Processing Record 48 of Set 6 | aranda de duero
# Processing Record 49 of Set 6 | ritchie
# Processing Record 50 of Set 6 | omboue
# Processing Record 1 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 2 of Set 7 | raudeberg
# Processing Record 3 of Set 7 | kouango
# Processing Record 4 of Set 7 | taoudenni
# Processing Record 5 of Set 7 | edd
# Processing Record 6 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 7 | marsh harbour
# Processing Record 8 of Set 7 | ilinskiy
# Processing Record 9 of Set 7 | faisalabad
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | santa vitoria do palmar
# Processing Record 12 of Set 7 | sao filipe
# Processing Record 13 of Set 7 | margate
# Processing Record 14 of Set 7 | buraydah
# Processing Record 15 of Set 7 | antofagasta
# Processing Record 16 of Set 7 | ankazobe
# Processing Record 17 of Set 7 | male
# Processing Record 18 of Set 7 | maniitsoq
# Processing Record 19 of Set 7 | pitimbu
# Processing Record 20 of Set 7 | sawakin
# Processing Record 21 of Set 7 | morondava
# Processing Record 22 of Set 7 | surab
# Processing Record 23 of Set 7 | ampanihy
# Processing Record 24 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | qandala
# Processing Record 26 of Set 7 | saint-louis
# Processing Record 27 of Set 7 | belyy yar
# Processing Record 28 of Set 7 | eyl
# Processing Record 29 of Set 7 | sandanski
# Processing Record 30 of Set 7 | aleksandrov gay
# Processing Record 31 of Set 7 | pokhara
# Processing Record 32 of Set 7 | aswan
# Processing Record 33 of Set 7 | rosario do sul
# Processing Record 34 of Set 7 | amapa
# Processing Record 35 of Set 7 | pakhtakoron
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | dhidhdhoo
# Processing Record 38 of Set 7 | omaruru
# Processing Record 39 of Set 7 | chabahar
# Processing Record 40 of Set 7 | somerset
# Processing Record 41 of Set 7 | mazagao
# Processing Record 42 of Set 7 | vila franca do campo
# Processing Record 43 of Set 7 | rio do sul
# Processing Record 44 of Set 7 | atasu
# Processing Record 45 of Set 7 | qabis
# City not found. Skipping...
# Processing Record 46 of Set 7 | montepuez
# Processing Record 47 of Set 7 | solton
# Processing Record 48 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 7 | jatai
# Processing Record 50 of Set 7 | altay
# Processing Record 1 of Set 8 | anloga
# Processing Record 2 of Set 8 | beloha
# Processing Record 3 of Set 8 | jutai
# Processing Record 4 of Set 8 | toguchin
# Processing Record 5 of Set 8 | johnstown
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | port shepstone
# Processing Record 8 of Set 8 | jardim
# Processing Record 9 of Set 8 | saint-denis
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | rincon
# Processing Record 12 of Set 8 | beyneu
# Processing Record 13 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 8 | girau do ponciano
# Processing Record 15 of Set 8 | mitsamiouli
# Processing Record 16 of Set 8 | kaoma
# Processing Record 17 of Set 8 | los llanos de aridane
# Processing Record 18 of Set 8 | pointe michel
# Processing Record 19 of Set 8 | shakhrinau
# City not found. Skipping...
# Processing Record 20 of Set 8 | san lawrenz
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | presidencia roque saenz pena
# Processing Record 23 of Set 8 | sorland
# Processing Record 24 of Set 8 | kolyvan
# Processing Record 25 of Set 8 | khorixas
# Processing Record 26 of Set 8 | saint anthony
# Processing Record 27 of Set 8 | oswego
# Processing Record 28 of Set 8 | port hawkesbury
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | navalcarnero
# Processing Record 31 of Set 8 | gamba
# Processing Record 32 of Set 8 | thompson
# Processing Record 33 of Set 8 | giera
# Processing Record 34 of Set 8 | bilaua
# City not found. Skipping...
# Processing Record 35 of Set 8 | yar-sale
# Processing Record 36 of Set 8 | lamballe
# Processing Record 37 of Set 8 | ust-koksa
# Processing Record 38 of Set 8 | tevriz
# Processing Record 39 of Set 8 | sassandra
# Processing Record 40 of Set 8 | minna
# Processing Record 41 of Set 8 | aliwal north
# Processing Record 42 of Set 8 | rocha
# Processing Record 43 of Set 8 | chor
# Processing Record 44 of Set 8 | ladario
# Processing Record 45 of Set 8 | skelleftea
# Processing Record 46 of Set 8 | canelones
# Processing Record 47 of Set 8 | leh
# Processing Record 48 of Set 8 | usinsk
# Processing Record 49 of Set 8 | necochea
# Processing Record 50 of Set 8 | pozo colorado
# Processing Record 1 of Set 9 | harper
# Processing Record 2 of Set 9 | kavaratti
# Processing Record 3 of Set 9 | tamandare
# Processing Record 4 of Set 9 | pietermaritzburg
# Processing Record 5 of Set 9 | epe
# Processing Record 6 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 7 of Set 9 | pogradec
# Processing Record 8 of Set 9 | kaputa
# Processing Record 9 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 10 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 9 | lucea
# Processing Record 12 of Set 9 | salisbury
# Processing Record 13 of Set 9 | matara
# Processing Record 14 of Set 9 | kongoussi
# Processing Record 15 of Set 9 | kostomuksha
# Processing Record 16 of Set 9 | marzuq
# Processing Record 17 of Set 9 | havre-saint-pierre
# Processing Record 18 of Set 9 | joshimath
# Processing Record 19 of Set 9 | akdepe
# Processing Record 20 of Set 9 | nicoya
# Processing Record 21 of Set 9 | ochakiv
# Processing Record 22 of Set 9 | high point
# Processing Record 23 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 9 | havoysund
# Processing Record 25 of Set 9 | marawi
# Processing Record 26 of Set 9 | fomboni
# Processing Record 27 of Set 9 | muli
# Processing Record 28 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 9 | chimbote
# Processing Record 30 of Set 9 | dutlwe
# Processing Record 31 of Set 9 | ratnagiri
# Processing Record 32 of Set 9 | dowa
# Processing Record 33 of Set 9 | tocopilla
# Processing Record 34 of Set 9 | qaqortoq
# Processing Record 35 of Set 9 | velsk
# Processing Record 36 of Set 9 | olean
# Processing Record 37 of Set 9 | kantabanji
# Processing Record 38 of Set 9 | itanhem
# Processing Record 39 of Set 9 | maneromango
# Processing Record 40 of Set 9 | buenos aires
# Processing Record 41 of Set 9 | severodvinsk
# Processing Record 42 of Set 9 | sume
# Processing Record 43 of Set 9 | shambu
# Processing Record 44 of Set 9 | vitre
# Processing Record 45 of Set 9 | rabak
# Processing Record 46 of Set 9 | galle
# Processing Record 47 of Set 9 | fort-shevchenko
# Processing Record 48 of Set 9 | dno
# Processing Record 49 of Set 9 | coquimbo
# Processing Record 50 of Set 9 | sabha
# Processing Record 1 of Set 10 | antalaha
# Processing Record 2 of Set 10 | adamovka
# Processing Record 3 of Set 10 | murgab
# Processing Record 4 of Set 10 | macusani
# Processing Record 5 of Set 10 | sape
# Processing Record 6 of Set 10 | mogadishu
# Processing Record 7 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 10 | ajdabiya
# Processing Record 10 of Set 10 | kisangani
# Processing Record 11 of Set 10 | manta
# Processing Record 12 of Set 10 | sheregesh
# Processing Record 13 of Set 10 | hualmay
# Processing Record 14 of Set 10 | la mana
# Processing Record 15 of Set 10 | port-gentil
# Processing Record 16 of Set 10 | lobito
# Processing Record 17 of Set 10 | filadelfia
# Processing Record 18 of Set 10 | alvand
# Processing Record 19 of Set 10 | werota
# Processing Record 20 of Set 10 | chitral
# Processing Record 21 of Set 10 | damghan
# Processing Record 22 of Set 10 | tibu
# Processing Record 23 of Set 10 | yellandu
# Processing Record 24 of Set 10 | naifaru
# Processing Record 25 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 10 | garowe
# Processing Record 27 of Set 10 | golpayegan
# Processing Record 28 of Set 10 | grand gaube
# Processing Record 29 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 10 | pimampiro
# Processing Record 31 of Set 10 | tikhvin
# Processing Record 32 of Set 10 | hobyo
# Processing Record 33 of Set 10 | klos
# Processing Record 34 of Set 10 | columbus
# Processing Record 35 of Set 10 | arak
# Processing Record 36 of Set 10 | cabinda
# Processing Record 37 of Set 10 | labrea
# Processing Record 38 of Set 10 | boffa
# Processing Record 39 of Set 10 | mehamn
# Processing Record 40 of Set 10 | middlebury
# Processing Record 41 of Set 10 | mahon
# Processing Record 42 of Set 10 | hambantota
# Processing Record 43 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 10 | mahibadhoo
# Processing Record 45 of Set 10 | plettenberg bay
# Processing Record 46 of Set 10 | gombe
# Processing Record 47 of Set 10 | rio grande
# Processing Record 48 of Set 10 | solano
# Processing Record 49 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 50 of Set 10 | sayalgudi
# City not found. Skipping...
# Processing Record 1 of Set 11 | charlestown
# Processing Record 2 of Set 11 | kibungo
# Processing Record 3 of Set 11 | tromso
# Processing Record 4 of Set 11 | beira
# Processing Record 5 of Set 11 | abu dhabi
# Processing Record 6 of Set 11 | monte alegre
# Processing Record 7 of Set 11 | frontignan
# Processing Record 8 of Set 11 | joensuu
# Processing Record 9 of Set 11 | polovinnoye
# Processing Record 10 of Set 11 | boende
# Processing Record 11 of Set 11 | trairi
# Processing Record 12 of Set 11 | abhar
# Processing Record 13 of Set 11 | verdalsora
# City not found. Skipping...
# Processing Record 14 of Set 11 | tukrah
# Processing Record 15 of Set 11 | mozarlandia
# Processing Record 16 of Set 11 | porto novo
# Processing Record 17 of Set 11 | paris
# Processing Record 18 of Set 11 | skibbereen
# Processing Record 19 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 20 of Set 11 | vagur
# Processing Record 21 of Set 11 | brae
# Processing Record 22 of Set 11 | pavilosta
# Processing Record 23 of Set 11 | copiapo
# Processing Record 24 of Set 11 | lagos
# Processing Record 25 of Set 11 | campina verde
# Processing Record 26 of Set 11 | ituporanga
# Processing Record 27 of Set 11 | emba
# Processing Record 28 of Set 11 | maragheh
# Processing Record 29 of Set 11 | isabela
# Processing Record 30 of Set 11 | vuktyl
# Processing Record 31 of Set 11 | yining
# Processing Record 32 of Set 11 | owando
# Processing Record 33 of Set 11 | nisia floresta
# Processing Record 34 of Set 11 | tucuma
# Processing Record 35 of Set 11 | dabat
# Processing Record 36 of Set 11 | sotouboua
# Processing Record 37 of Set 11 | puquio
# Processing Record 38 of Set 11 | murindo
# Processing Record 39 of Set 11 | naron
# Processing Record 40 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 11 | at-bashi
# Processing Record 43 of Set 11 | maues
# Processing Record 44 of Set 11 | ostrovnoy
# Processing Record 45 of Set 11 | maxixe
# Processing Record 46 of Set 11 | bismil
# Processing Record 47 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 11 | moyale
# Processing Record 49 of Set 11 | saint-joseph
# Processing Record 50 of Set 11 | porto uniao
# Processing Record 1 of Set 12 | puri
# Processing Record 2 of Set 12 | kingston
# Processing Record 3 of Set 12 | jaciara
# Processing Record 4 of Set 12 | sorgun
# Processing Record 5 of Set 12 | lesnoy
# Processing Record 6 of Set 12 | matsanga
# City not found. Skipping...
# Processing Record 7 of Set 12 | barcelona
# Processing Record 8 of Set 12 | luanda
# Processing Record 9 of Set 12 | mormugao
# Processing Record 10 of Set 12 | moroto
# Processing Record 11 of Set 12 | burgeo
# Processing Record 12 of Set 12 | lasa
# Processing Record 13 of Set 12 | outjo
# Processing Record 14 of Set 12 | damaturu
# Processing Record 15 of Set 12 | roanoke rapids
# Processing Record 16 of Set 12 | petersburg
# Processing Record 17 of Set 12 | san luis
# Processing Record 18 of Set 12 | rubizhne
# Processing Record 19 of Set 12 | mossendjo
# Processing Record 20 of Set 12 | tazovskiy
# Processing Record 21 of Set 12 | road town
# Processing Record 22 of Set 12 | tanda
# Processing Record 23 of Set 12 | xai-xai
# Processing Record 24 of Set 12 | belyy
# Processing Record 25 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 26 of Set 12 | umm lajj
# Processing Record 27 of Set 12 | salinopolis
# Processing Record 28 of Set 12 | walvis bay
# Processing Record 29 of Set 12 | lakselv
# Processing Record 30 of Set 12 | strazske
# Processing Record 31 of Set 12 | douentza
# Processing Record 32 of Set 12 | luxeuil-les-bains
# Processing Record 33 of Set 12 | pryazha
# Processing Record 34 of Set 12 | dolores
# Processing Record 35 of Set 12 | kastamonu
# Processing Record 36 of Set 12 | kangaatsiaq
# Processing Record 37 of Set 12 | saint-georges
# Processing Record 38 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 39 of Set 12 | kalinagar
# Processing Record 40 of Set 12 | bonthe
# Processing Record 41 of Set 12 | kattivakkam
# Processing Record 42 of Set 12 | pitea
# Processing Record 43 of Set 12 | bodmin
# Processing Record 44 of Set 12 | karasburg
# Processing Record 45 of Set 12 | monte aprazivel
# Processing Record 46 of Set 12 | zitsa
# Processing Record 47 of Set 12 | mattru
# Processing Record 48 of Set 12 | pipri
# Processing Record 49 of Set 12 | bonfim
# Processing Record 50 of Set 12 | bad hersfeld
# Processing Record 1 of Set 13 | sumbawanga
# Processing Record 2 of Set 13 | kaabong
# Processing Record 3 of Set 13 | kolo
# Processing Record 4 of Set 13 | lodwar
# Processing Record 5 of Set 13 | bergen
# Processing Record 6 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 13 | bayan
# Processing Record 8 of Set 13 | gravdal
# Processing Record 9 of Set 13 | khanpur
# Processing Record 10 of Set 13 | eha amufu
# Processing Record 11 of Set 13 | ubatuba
# Processing Record 12 of Set 13 | itarema
# Processing Record 13 of Set 13 | san cristobal
# Processing Record 14 of Set 13 | nizhnevartovsk
# Processing Record 15 of Set 13 | inhambane
# Processing Record 16 of Set 13 | sergeyevka
# Processing Record 17 of Set 13 | kichmengskiy gorodok
# Processing Record 18 of Set 13 | reftinskiy
# Processing Record 19 of Set 13 | shelbyville
# Processing Record 20 of Set 13 | saint-felicien
# Processing Record 21 of Set 13 | kristiansund
# Processing Record 22 of Set 13 | maceio
# Processing Record 23 of Set 13 | bojnurd
# Processing Record 24 of Set 13 | state college
# Processing Record 25 of Set 13 | coihueco
# Processing Record 26 of Set 13 | shahpura
# Processing Record 27 of Set 13 | sucha beskidzka
# Processing Record 28 of Set 13 | mantua
# Processing Record 29 of Set 13 | kamien pomorski
# Processing Record 30 of Set 13 | jequitinhonha
# Processing Record 31 of Set 13 | nizhniy odes
# Processing Record 32 of Set 13 | gasa
# Processing Record 33 of Set 13 | dwarka
# Processing Record 34 of Set 13 | shipunovo
# Processing Record 35 of Set 13 | gibara
# Processing Record 36 of Set 13 | malmesbury
# Processing Record 37 of Set 13 | verkhne-katunskoye
# City not found. Skipping...
# Processing Record 38 of Set 13 | de aar
# Processing Record 39 of Set 13 | sosua
# Processing Record 40 of Set 13 | namanyere
# Processing Record 41 of Set 13 | karsun
# Processing Record 42 of Set 13 | manoel urbano
# Processing Record 43 of Set 13 | oktyabrskoye
# Processing Record 44 of Set 13 | botevgrad
# Processing Record 45 of Set 13 | altagracia de orituco
# Processing Record 46 of Set 13 | dmitrovsk-orlovskiy
# Processing Record 47 of Set 13 | gyomaendrod
# Processing Record 48 of Set 13 | wenchi
# Processing Record 49 of Set 13 | mechanicsville
# Processing Record 50 of Set 13 | sakakah
# Processing Record 1 of Set 14 | thalassery
# Processing Record 2 of Set 14 | sinjar
# Processing Record 3 of Set 14 | mehran
# Processing Record 4 of Set 14 | acari
# Processing Record 5 of Set 14 | bandundu
# Processing Record 6 of Set 14 | balad
# Processing Record 7 of Set 14 | arrecife
# Processing Record 8 of Set 14 | tupiza
# Processing Record 9 of Set 14 | elverum
# Processing Record 10 of Set 14 | caconda
# Processing Record 11 of Set 14 | the valley
# Processing Record 12 of Set 14 | santa rosa
# Processing Record 13 of Set 14 | machilipatnam
# Processing Record 14 of Set 14 | savannah bight
# Processing Record 15 of Set 14 | opuwo
# Processing Record 16 of Set 14 | san ramon
# Processing Record 17 of Set 14 | nyrob
# Processing Record 18 of Set 14 | mailsi
# Processing Record 19 of Set 14 | noyabrsk
# Processing Record 20 of Set 14 | svetlogorsk
# Processing Record 21 of Set 14 | kasane
# Processing Record 22 of Set 14 | esil
# Processing Record 23 of Set 14 | natal
# Processing Record 24 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 14 | mulchen
# Processing Record 26 of Set 14 | itaituba
# Processing Record 27 of Set 14 | puerto maldonado
# Processing Record 28 of Set 14 | shubarkuduk
# Processing Record 29 of Set 14 | valdivia
# Processing Record 30 of Set 14 | bantry
# Processing Record 31 of Set 14 | reconquista
# Processing Record 32 of Set 14 | aykino
# Processing Record 33 of Set 14 | kamyshin
# Processing Record 34 of Set 14 | andenes
# Processing Record 35 of Set 14 | boone
# Processing Record 36 of Set 14 | springbok
# Processing Record 37 of Set 14 | solbjerg
# Processing Record 38 of Set 14 | fjerritslev
# Processing Record 39 of Set 14 | segezha
# Processing Record 40 of Set 14 | obigarm
# Processing Record 41 of Set 14 | vallenar
# Processing Record 42 of Set 14 | mercedes
# Processing Record 43 of Set 14 | tutoia
# Processing Record 44 of Set 14 | urengoy
# Processing Record 45 of Set 14 | kalmunai
# Processing Record 46 of Set 14 | bosobolo
# Processing Record 47 of Set 14 | sao gabriel da cachoeira
# Processing Record 48 of Set 14 | la rioja
# Processing Record 49 of Set 14 | puerto leguizamo
# Processing Record 50 of Set 14 | taywarah
# Processing Record 1 of Set 15 | bengkulu
# Processing Record 2 of Set 15 | pauini
# Processing Record 3 of Set 15 | tabas
# Processing Record 4 of Set 15 | kiknur
# Processing Record 5 of Set 15 | libreville
# Processing Record 6 of Set 15 | kaka
# Processing Record 7 of Set 15 | neuquen
# Processing Record 8 of Set 15 | aku
# Processing Record 9 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 15 | vostochnyy
# Processing Record 11 of Set 15 | rutul
# Processing Record 12 of Set 15 | alexander city
# Processing Record 13 of Set 15 | itiuba
# Processing Record 14 of Set 15 | muzhi
# Processing Record 15 of Set 15 | alberton
# Processing Record 16 of Set 15 | khalkhal
# Processing Record 17 of Set 15 | udayagiri
# Processing Record 18 of Set 15 | bad wurzach
# Processing Record 19 of Set 15 | sinnar
# Processing Record 20 of Set 15 | finnsnes
# Processing Record 21 of Set 15 | mariestad
# Processing Record 22 of Set 15 | ongandjera
# Processing Record 23 of Set 15 | gotha
# Processing Record 24 of Set 15 | presidente olegario
# Processing Record 25 of Set 15 | pangody
# Processing Record 26 of Set 15 | semey
# Processing Record 27 of Set 15 | kozhva
# Processing Record 28 of Set 15 | jhunjhunun
# Processing Record 29 of Set 15 | cesme
# Processing Record 30 of Set 15 | jumla
# Processing Record 31 of Set 15 | wajir
# Processing Record 32 of Set 15 | aktau
# Processing Record 33 of Set 15 | sheltozero
# Processing Record 34 of Set 15 | llanes
# Processing Record 35 of Set 15 | bloemfontein
# Processing Record 36 of Set 15 | scarborough
# Processing Record 37 of Set 15 | porecatu
# Processing Record 38 of Set 15 | harrisonburg
# Processing Record 39 of Set 15 | la palma
# Processing Record 40 of Set 15 | sajanan
# Processing Record 41 of Set 15 | solenzo
# Processing Record 42 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 15 | dawlatabad
# Processing Record 44 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 15 | vranov
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Sechura      PE  -5.5569  -80.8222     71.55        69          71
# 1       Oriximina      BR  -1.7656  -55.8661     74.53        96          97
# 2           Lodja      CD  -3.4833   23.4333     66.36       100          96
# 3          Olkusz      PL  50.2813   19.5650     46.06        71          16
# 4            Lebu      CL -37.6167  -73.6500     50.02        72          60
# 5  Vestmannaeyjar      IS  63.4427  -20.2734     47.52        83          32
# 6         Qaanaaq      GL  77.4840  -69.3632      9.46        71          17
# 7     Port Alfred      ZA -33.5906   26.8910     58.17        81          24
# 8      Codrington      AU -38.2667  141.9667     58.95        59          37
# 9       Piacabucu      BR -10.4056  -36.4344     76.30        74          94
#
#    Wind Speed       Description
# 0       17.81     broken clouds
# 1        1.59     moderate rain
# 2        1.23   overcast clouds
# 3        3.89        few clouds
# 4       17.18     broken clouds
# 5       11.23  scattered clouds
# 6        4.88        few clouds
# 7        4.00        few clouds
# 8       19.66  scattered clouds
# 9        5.39   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
